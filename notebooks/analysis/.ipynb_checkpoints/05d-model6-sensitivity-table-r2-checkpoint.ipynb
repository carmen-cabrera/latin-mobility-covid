# %% [markdown]
# # Model 6 sensitivity table: imputed vs raw-adjusted

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Parameters

# %%
wd = '/Users/carmen/Library/CloudStorage/OneDrive-TheUniversityofLiverpool/research/latin-mobility-covid'

countries = {
    'Argentina': 'ARG',
    'Chile': 'CHL',
    'Colombia': 'COL',
}

groupings = ['density', 'rdi']
imputed_version = 'new'
raw_version = 'raw_adjusted_no_imputation_r2'
model = 6

# %% [markdown]
# # Helpers

# %%
def read_model_outputs(country_short, grouping, version, model_id):
    base = os.path.join(wd, 'data', 'outputs', country_short, 'mov-analysis', f'by-{grouping}')

    if version == 'new':
        tidy_file = os.path.join(base, 'data_trend_outflows_param_tidy_results_o_new.csv')
        re_file = os.path.join(base, f'data_trend_param_quad_m{model_id}o_re_new.csv')
    else:
        tidy_file = os.path.join(base, f'data_trend_outflows_param_tidy_results_o_{version}.csv')
        re_file = os.path.join(base, f'data_trend_param_quad_m{model_id}o_re_{version}.csv')

    df_tidy = pd.read_csv(tidy_file)
    df_re = pd.read_csv(re_file)
    return df_tidy, df_re


def extract_model_by_category(df_tidy, df_re, country_short, grouping, data_version, model_id):
    df_model = df_tidy[df_tidy['model'] == model_id].copy().reset_index(drop=True)

    fe_intercept = (
        df_model[df_model['term'].str.contains('Intercept')]['estimate']
        .reset_index(drop=True)
        .loc[0]
    )
    fe_time = df_model[df_model['term'] == 'time']['estimate'].reset_index(drop=True).loc[0]
    fe_time2 = df_model[df_model['term'] == 'time2']['estimate'].reset_index(drop=True).loc[0]

    re_intercept = df_re[df_re['facet'].str.contains('Intercept')].reset_index(drop=True)
    re_time = df_re[df_re['facet'] == 'time'].reset_index(drop=True)

    rows = []
    n_rows = min(len(re_intercept), len(re_time))
    for i in range(n_rows):
        category = re_intercept.loc[i, 'term']
        rows.append({
            'country': country_short,
            'grouping': grouping,
            'category': category,
            'data_version': data_version,
            'model': model_id,
            'intercept_estimate': fe_intercept + re_intercept.loc[i, 'estimate'],
            'intercept_conf_low': fe_intercept + re_intercept.loc[i, 'conf.low'],
            'intercept_conf_high': fe_intercept + re_intercept.loc[i, 'conf.high'],
            'time_estimate': fe_time + re_time.loc[i, 'estimate'],
            'time_conf_low': fe_time + re_time.loc[i, 'conf.low'],
            'time_conf_high': fe_time + re_time.loc[i, 'conf.high'],
            'time2_estimate': fe_time2,
        })

    return pd.DataFrame(rows)


def needs_model5_fallback(df_extracted):
    check_cols = [
        'intercept_estimate', 'intercept_conf_low', 'intercept_conf_high',
        'time_estimate', 'time_conf_low', 'time_conf_high',
    ]
    return df_extracted[check_cols].isna().any().any()


def extract_with_fallback(country_short, grouping, data_version):
    df_tidy, df_re = read_model_outputs(country_short, grouping, data_version, model_id=6)
    df_extracted = extract_model_by_category(df_tidy, df_re, country_short, grouping, data_version, model_id=6)

    if needs_model5_fallback(df_extracted):
        df_tidy, df_re = read_model_outputs(country_short, grouping, data_version, model_id=5)
        df_extracted = extract_model_by_category(df_tidy, df_re, country_short, grouping, data_version, model_id=5)

    return df_extracted


def order_categories(df_plot):
    df_plot = df_plot.copy()
    df_plot['category_num'] = pd.to_numeric(df_plot['category'], errors='coerce')
    if df_plot['category_num'].notna().all():
        df_plot = df_plot.sort_values('category_num').reset_index(drop=True)
        df_plot['x'] = df_plot['category_num']
    else:
        df_plot = df_plot.sort_values('category').reset_index(drop=True)
        df_plot['x'] = np.arange(1, len(df_plot) + 1)
    return df_plot


def get_axis_limits(df_long, estimate_col, low_col, high_col, padding_ratio=0.08):
    values = pd.concat([
        df_long[estimate_col],
        df_long[low_col],
        df_long[high_col],
    ], axis=0).replace([np.inf, -np.inf], np.nan).dropna()

    if len(values) == 0:
        return None

    vmin = values.min()
    vmax = values.max()
    span = vmax - vmin
    pad = span * padding_ratio if span > 0 else max(abs(vmin) * padding_ratio, 0.1)
    return (vmin - pad, vmax + pad)


def plot_model6_comparison(df_long, country_short, grouping, plot_dir, intercept_ylim=None, time_ylim=None):
    subset = df_long[(df_long['country'] == country_short) & (df_long['grouping'] == grouping)].copy()
    subset = order_categories(subset)

    label_map = {
        'new': 'Imputed',
        'raw_adjusted_no_imputation_r2': 'Raw adjusted, no imputation',
    }
    color_map = {
        'new': 'lightsalmon',
        'raw_adjusted_no_imputation_r2': 'crimson',
    }
    offset_map = {
        'new': -0.08,
        'raw_adjusted_no_imputation_r2': 0.08,
    }
    title_grouping = 'Population density' if grouping == 'density' else 'Relative deprivation'

    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(9, 10), sharex=True)

    for ax in [ax1, ax2]:
        ax.tick_params(axis='both', which='both', width=0, length=0, color='k', labelsize=16, pad=9)
        ax.axhline(0, color='k', linestyle=':', linewidth=2, zorder=0)

    for version in ['new', 'raw_adjusted_no_imputation_r2']:
        df_version = subset[subset['data_version'] == version].copy().reset_index(drop=True)
        x = df_version['x'] + offset_map[version]

        intercept_left = df_version['intercept_estimate'] - df_version['intercept_conf_low']
        intercept_right = df_version['intercept_conf_high'] - df_version['intercept_estimate']
        ax1.errorbar(
            x,
            df_version['intercept_estimate'],
            yerr=[intercept_left, intercept_right],
            fmt='o',
            linewidth=3,
            markersize=8,
            color=color_map[version],
            label=label_map[version],
        )

        time_left = df_version['time_estimate'] - df_version['time_conf_low']
        time_right = df_version['time_conf_high'] - df_version['time_estimate']
        ax2.errorbar(
            x,
            df_version['time_estimate'],
            yerr=[time_left, time_right],
            fmt='o',
            linewidth=3,
            markersize=8,
            color=color_map[version],
            label=label_map[version],
        )

    xticks = subset[['category', 'x']].drop_duplicates().sort_values('x')
    if intercept_ylim is not None:
        ax1.set_ylim(intercept_ylim)
    if time_ylim is not None:
        ax2.set_ylim(time_ylim)
    ax1.set_ylabel('Intercept', fontsize=18)
    ax2.set_ylabel('Time', fontsize=18)
    ax2.set_xlabel('Category', fontsize=18)
    ax2.set_xticks(xticks['x'], xticks['category'])
    ax2.tick_params(axis='x', labelsize=14)
    ax1.legend(frameon=False, fontsize=12, loc='best')
    fig.suptitle(f'{country_short} - {title_grouping}', fontsize=18, y=0.98)
    plt.tight_layout()

    plot_path = os.path.join(plot_dir, f'{country_short}_{grouping}_model6_imputed_vs_raw_r2.pdf')
    plt.savefig(plot_path, bbox_inches='tight')
    plt.show()
    return plot_path

# %% [markdown]
# # Build long-format comparison table

# %%
all_rows = []

for country, country_short in countries.items():
    for grouping in groupings:
        for version in [imputed_version, raw_version]:
            all_rows.append(extract_with_fallback(country_short, grouping, version))

df_long = pd.concat(all_rows, ignore_index=True)
df_long = df_long.sort_values(['country', 'grouping', 'category', 'data_version']).reset_index(drop=True)
df_long
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/envs/geo-env-new/lib/python3.10/site-packages/pandas/core/indexes/range.py:391, in RangeIndex.get_loc(self, key, method, tolerance)
#     390 try:
# --> 391     return self._range.index(new_key)
#     392 except ValueError as err:
#
# ValueError: 0 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 6
#       4     for grouping in groupings:
#       5         for version in [imputed_version, raw_version]:
# ----> 6             all_rows.append(extract_with_fallback(country_short, grouping, version))
#       8 df_long = pd.concat(all_rows, ignore_index=True)
#       9 df_long = df_long.sort_values(['country', 'grouping', 'category', 'data_version']).reset_index(drop=True)
#
# Cell In[13], line 66, in extract_with_fallback(country_short, grouping, data_version)
#      64 if needs_model5_fallback(df_extracted):
#      65     df_tidy, df_re = read_model_outputs(country_short, grouping, data_version, model_id=5)
# ---> 66     df_extracted = extract_model_by_category(df_tidy, df_re, country_short, grouping, data_version, model_id=5)
#      68 return df_extracted
#
# Cell In[13], line 25, in extract_model_by_category(df_tidy, df_re, country_short, grouping, data_version, model_id)
#      19 fe_intercept = (
#      20     df_model[df_model['term'].str.contains('Intercept')]['estimate']
#      21     .reset_index(drop=True)
#      22     .loc[0]
#      23 )
#      24 fe_time = df_model[df_model['term'] == 'time']['estimate'].reset_index(drop=True).loc[0]
# ---> 25 fe_time2 = df_model[df_model['term'] == 'time2']['estimate'].reset_index(drop=True).loc[0]
#      27 re_intercept = df_re[df_re['facet'].str.contains('Intercept')].reset_index(drop=True)
#      28 re_time = df_re[df_re['facet'] == 'time'].reset_index(drop=True)
#
# File ~/anaconda3/envs/geo-env-new/lib/python3.10/site-packages/pandas/core/indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/anaconda3/envs/geo-env-new/lib/python3.10/site-packages/pandas/core/indexing.py:1312, in _LocIndexer._getitem_axis(self, key, axis)
#    1310 # fall thru to straight lookup
#    1311 self._validate_key(key, axis)
# -> 1312 return self._get_label(key, axis=axis)
#
# File ~/anaconda3/envs/geo-env-new/lib/python3.10/site-packages/pandas/core/indexing.py:1260, in _LocIndexer._get_label(self, label, axis)
#    1258 def _get_label(self, label, axis: int):
#    1259     # GH#5567 this will fail if the label is not present in the axis.
# -> 1260     return self.obj.xs(label, axis=axis)
#
# File ~/anaconda3/envs/geo-env-new/lib/python3.10/site-packages/pandas/core/generic.py:4056, in NDFrame.xs(self, key, axis, level, drop_level)
#    4054             new_index = index[loc]
#    4055 else:
# -> 4056     loc = index.get_loc(key)
#    4058     if isinstance(loc, np.ndarray):
#    4059         if loc.dtype == np.bool_:
#
# File ~/anaconda3/envs/geo-env-new/lib/python3.10/site-packages/pandas/core/indexes/range.py:393, in RangeIndex.get_loc(self, key, method, tolerance)
#     391         return self._range.index(new_key)
#     392     except ValueError as err:
# --> 393         raise KeyError(key) from err
#     394 self._check_indexing_error(key)
#     395 raise KeyError(key)
#
# KeyError: 0

# %% [markdown]
# # Build wide-format supplementary table

# %%
value_columns = [
    'intercept_estimate',
    'intercept_conf_low',
    'intercept_conf_high',
    'time_estimate',
    'time_conf_low',
    'time_conf_high',
    'time2_estimate',
]

df_wide = df_long.pivot_table(
    index=['country', 'grouping', 'category'],
    columns='data_version',
    values=value_columns,
    aggfunc='first',
)

df_wide.columns = [f'{metric}_{version}' for metric, version in df_wide.columns]
df_wide = df_wide.reset_index()
df_wide = df_wide.sort_values(['country', 'grouping', 'category']).reset_index(drop=True)
df_wide
# Out:
#    country grouping  category  intercept_conf_high_new  \
# 0      ARG  density         0               -16.524111
# 1      ARG  density         1               -22.829427
# 2      ARG  density         2               -24.345307
# 3      ARG  density         3               -26.745226
# 4      ARG  density         4               -31.411514
# 5      ARG      rdi         0                      NaN
# 6      ARG      rdi         1                      NaN
# 7      ARG      rdi         2                      NaN
# 8      CHL  density         0               -33.989537
# 9      CHL  density         1               -43.719235
# 10     CHL  density         2               -47.810797
# 11     CHL  density         3               -47.537294
# 12     CHL  density         4               -50.860917
# 13     CHL      rdi         0               -45.830426
# 14     CHL      rdi         1               -34.816121
# 15     CHL      rdi         2               -23.038717
# 16     COL  density         0               -10.429274
# 17     COL  density         1               -36.780158
# 18     COL  density         2               -41.912050
# 19     COL  density         3               -45.060838
# 20     COL  density         4               -51.919202
# 21     COL      rdi         0               -40.440446
# 22     COL      rdi         1                 7.055829
# 23     COL      rdi         2                57.595302
#
#     intercept_conf_high_raw_adjusted_no_imputation_r2  intercept_conf_low_new  \
# 0                                          -18.394827              -22.332399
# 1                                          -22.729984              -28.637997
# 2                                          -24.600499              -30.153819
# 3                                          -27.064810              -32.553250
# 4                                          -31.556510              -37.219751
# 5                                          -22.014546                     NaN
# 6                                          -15.179991                     NaN
# 7                                           -4.473880                     NaN
# 8                                          -35.732958              -40.336039
# 9                                          -43.620638              -50.065729
# 10                                         -47.503730              -54.157290
# 11                                         -47.716628              -53.883792
# 12                                         -50.895262              -57.207403
# 13                                         -46.438952              -54.917417
# 14                                         -36.280942              -43.903140
# 15                                         -30.131242              -32.125705
# 16                                         -25.746926              -20.330972
# 17                                         -38.354453              -46.681856
# 18                                         -43.213086              -51.813747
# 19                                         -46.321006              -54.962538
# 20                                         -53.135213              -61.820899
# 21                                         -44.805844              -59.285195
# 22                                         -20.022058              -11.788920
# 23                                          -3.762858               38.750553
#
#     intercept_conf_low_raw_adjusted_no_imputation_r2  intercept_estimate_new  \
# 0                                         -23.903063              -19.428255
# 1                                         -28.238150              -25.733712
# 2                                         -30.108902              -27.249563
# 3                                         -32.572875              -29.649238
# 4                                         -37.064710              -34.315632
# 5                                         -30.020421              -26.004769
# 6                                         -23.185969              -18.432917
# 7                                         -12.479688                5.420749
# 8                                         -41.726168              -37.162788
# 9                                         -49.613841              -46.892482
# 10                                        -53.496923              -50.984044
# 11                                        -53.709826              -50.710543
# 12                                        -56.888452              -54.034160
# 13                                        -54.163506              -50.373922
# 14                                        -44.005676              -39.359630
# 15                                        -37.855841              -27.582211
# 16                                        -33.682033              -15.380123
# 17                                        -46.289557              -41.731007
# 18                                        -51.148190              -46.862899
# 19                                        -54.256116              -50.011688
# 20                                        -61.070318              -56.870050
# 21                                        -57.041859              -49.862821
# 22                                        -32.258073               -2.366545
# 23                                        -15.998874               48.172928
#
#     intercept_estimate_raw_adjusted_no_imputation_r2  time2_estimate_new  \
# 0                                         -21.148945           -0.000857
# 1                                         -25.484067           -0.000857
# 2                                         -27.354700           -0.000857
# 3                                         -29.818842           -0.000857
# 4                                         -34.310610           -0.000857
# 5                                         -26.017484           -0.000441
# 6                                         -19.182980           -0.000441
# 7                                          -8.476784           -0.000441
# 8                                         -38.729563           -0.000106
# 9                                         -46.617240           -0.000106
# 10                                        -50.500326           -0.000106
# 11                                        -50.713227           -0.000106
# 12                                        -53.891857           -0.000106
# 13                                        -50.301229           -0.000046
# 14                                        -40.143309           -0.000046
# 15                                        -33.993542           -0.000046
# 16                                        -29.714480           -0.000434
# 17                                        -42.322005           -0.000434
# 18                                        -47.180638           -0.000434
# 19                                        -50.288561           -0.000434
# 20                                        -57.102765           -0.000434
# 21                                        -50.923852           -0.000082
# 22                                        -26.140065           -0.000082
# 23                                         -9.880866           -0.000082
#
#     time2_estimate_raw_adjusted_no_imputation_r2  time_conf_high_new  \
# 0                                      -0.000869            0.565459
# 1                                      -0.000869            0.528725
# 2                                      -0.000869            0.584416
# 3                                      -0.000869            0.550897
# 4                                      -0.000869            0.551353
# 5                                      -0.000519                 NaN
# 6                                      -0.000519                 NaN
# 7                                      -0.000519                 NaN
# 8                                      -0.000111            0.607039
# 9                                      -0.000111            0.619587
# 10                                     -0.000111            0.590503
# 11                                     -0.000111            0.503199
# 12                                     -0.000111            0.522980
# 13                                     -0.000056            0.566333
# 14                                     -0.000056            0.604660
# 15                                     -0.000056            0.666834
# 16                                     -0.000436            0.673528
# 17                                     -0.000436            0.661754
# 18                                     -0.000436            0.637153
# 19                                     -0.000436            0.570757
# 20                                     -0.000436            0.624468
# 21                                     -0.000202            0.580852
# 22                                     -0.000202            0.638635
# 23                                     -0.000202            0.582306
#
#     time_conf_high_raw_adjusted_no_imputation_r2  time_conf_low_new  \
# 0                                       0.541222           0.193773
# 1                                       0.544051           0.156697
# 2                                       0.611669           0.212449
# 3                                       0.580361           0.179523
# 4                                       0.577854           0.179732
# 5                                       0.688124                NaN
# 6                                       0.626546                NaN
# 7                                       0.541562                NaN
# 8                                       0.527097           0.038794
# 9                                       0.576977           0.051345
# 10                                      0.546573           0.022262
# 11                                      0.471668          -0.065045
# 12                                      0.491089          -0.045258
# 13                                      0.435836          -0.040389
# 14                                      0.455568          -0.002094
# 15                                      0.473163           0.060115
# 16                                      0.560474           0.175624
# 17                                      0.587578           0.163851
# 18                                      0.577750           0.139253
# 19                                      0.519731           0.072848
# 20                                      0.572966           0.126566
# 21                                      0.705807           0.090381
# 22                                      0.682679           0.148159
# 23                                      0.565305           0.091835
#
#     time_conf_low_raw_adjusted_no_imputation_r2  time_estimate_new  \
# 0                                      0.107941           0.379616
# 1                                      0.110808           0.342711
# 2                                      0.178244           0.398432
# 3                                      0.147191           0.365210
# 4                                      0.144587           0.365543
# 5                                     -0.042961           0.328113
# 6                                     -0.104634           0.328797
# 7                                     -0.189476           0.330953
# 8                                      0.015261           0.322916
# 9                                      0.065144           0.335466
# 10                                     0.034745           0.306382
# 11                                    -0.040162           0.219077
# 12                                    -0.020737           0.238861
# 13                                     0.065974           0.262972
# 14                                     0.085141           0.301283
# 15                                     0.103152           0.363474
# 16                                     0.154670           0.424576
# 17                                     0.181778           0.412802
# 18                                     0.171953           0.388203
# 19                                     0.113918           0.321803
# 20                                     0.167165           0.375517
# 21                                    -0.033300           0.335616
# 22                                    -0.056429           0.393397
# 23                                    -0.173802           0.337071
#
#     time_estimate_raw_adjusted_no_imputation_r2
# 0                                      0.324582
# 1                                      0.327429
# 2                                      0.394956
# 3                                      0.363776
# 4                                      0.361221
# 5                                      0.322582
# 6                                      0.260956
# 7                                      0.176043
# 8                                      0.271179
# 9                                      0.321060
# 10                                     0.290659
# 11                                     0.215753
# 12                                     0.235176
# 13                                     0.250905
# 14                                     0.270354
# 15                                     0.288158
# 16                                     0.357572
# 17                                     0.384678
# 18                                     0.374851
# 19                                     0.316825
# 20                                     0.370065
# 21                                     0.336254
# 22                                     0.313125
# 23                                     0.195751

# %% [markdown]
# # Plot Model 6 comparisons

# %%
plot_dir = os.path.join(wd, 'plots', 'model6-sensitivity-r2')
os.makedirs(plot_dir, exist_ok=True)

intercept_ylim = get_axis_limits(df_long, 'intercept_estimate', 'intercept_conf_low', 'intercept_conf_high')
time_ylim = get_axis_limits(df_long, 'time_estimate', 'time_conf_low', 'time_conf_high')

plot_paths = []
for country_short in countries.values():
    for grouping in groupings:
        plot_paths.append(
            plot_model6_comparison(
                df_long,
                country_short,
                grouping,
                plot_dir,
                intercept_ylim=intercept_ylim,
                time_ylim=time_ylim,
            )
        )

plot_paths
# Out:
# ['/Users/carmen/Library/CloudStorage/OneDrive-TheUniversityofLiverpool/research/latin-mobility-covid/plots/model6-sensitivity-r2/ARG_density_model6_imputed_vs_raw_r2.pdf',
#  '/Users/carmen/Library/CloudStorage/OneDrive-TheUniversityofLiverpool/research/latin-mobility-covid/plots/model6-sensitivity-r2/ARG_rdi_model6_imputed_vs_raw_r2.pdf',
#  '/Users/carmen/Library/CloudStorage/OneDrive-TheUniversityofLiverpool/research/latin-mobility-covid/plots/model6-sensitivity-r2/CHL_density_model6_imputed_vs_raw_r2.pdf',
#  '/Users/carmen/Library/CloudStorage/OneDrive-TheUniversityofLiverpool/research/latin-mobility-covid/plots/model6-sensitivity-r2/CHL_rdi_model6_imputed_vs_raw_r2.pdf',
#  '/Users/carmen/Library/CloudStorage/OneDrive-TheUniversityofLiverpool/research/latin-mobility-covid/plots/model6-sensitivity-r2/COL_density_model6_imputed_vs_raw_r2.pdf',
#  '/Users/carmen/Library/CloudStorage/OneDrive-TheUniversityofLiverpool/research/latin-mobility-covid/plots/model6-sensitivity-r2/COL_rdi_model6_imputed_vs_raw_r2.pdf']

# %% [markdown]
# # Save outputs

# %%
output_dir = os.path.join(wd, 'data', 'outputs', 'supplementary-tables')
os.makedirs(output_dir, exist_ok=True)

long_path = os.path.join(output_dir, 'model6-sensitivity-imputed-vs-raw-adjusted-long-r2.csv')
wide_path = os.path.join(output_dir, 'model6-sensitivity-imputed-vs-raw-adjusted-table-r2.csv')

df_long.to_csv(long_path, index=False)
df_wide.to_csv(wide_path, index=False)

print(long_path)
print(wide_path)
