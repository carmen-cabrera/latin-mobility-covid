# %%
import matplotlib.pyplot as plt
import numpy as np
import math
import pandas as pd
import statsmodels.api as sm
from scipy.special import gamma, loggamma, factorial
import scipy.stats
from scipy.interpolate import interp1d
from matplotlib.ticker import AutoMinorLocator 
from matplotlib import rc, font_manager
from matplotlib.lines import Line2D
from matplotlib import colors as mcolors
from mycolorpy import colorlist as mcp
from matplotlib import legend_handler
from matplotlib_scalebar.scalebar import ScaleBar
from mpl_toolkits.axes_grid1 import make_axes_locatable, axes_size
import collections
import matplotlib
import shapely.geometry
from shapely.geometry import Point
import shapely.ops 
from geopy.geocoders import Nominatim
import geopandas as gpd
import mapclassify
import jenkspy
import contextily as cx
import os
import rioxarray as rx
import pyreadr
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn import metrics
from pysal.lib import weights
from libpysal.io import open as psopen
# import plots
import seaborn as sns
from datetime import datetime, timedelta
import jenkspy
import warnings
from statsmodels.tsa.seasonal import seasonal_decompose
import statsmodels.formula.api as smf
warnings.filterwarnings("ignore")

# %%
wd = '/Users/carmen/Library/CloudStorage/OneDrive-TheUniversityofLiverpool/research/RECAST/latin-mobility-covid-local-files'

country = 'Colombia'

if country=='Argentina':
    country_short = 'ARG'
    country_code = 'AR'
elif country == 'Chile':
    country_short = 'CHL'
    country_code = 'CL'
elif country == 'Colombia':
    country_short = 'COL'
    country_code = 'CO'
    
category = 'density'

# %%
place = 'fuas'

# %%
# df = pd.read_csv(wd + '/data/outputs/' + country_short + '/mov-analysis/by-' + category + '/data_trend_netflows_capital_param_tidy_results_cat.csv')
# df_m3_re = pd.read_csv(wd + '/data/outputs/' + country_short + '/mov-analysis/by-' + category + '/data_trend_param_' + place + '_m3cat_re.csv')
# df_m4_re = pd.read_csv(wd + '/data/outputs/' + country_short + '/mov-analysis/by-' + category + '/data_trend_param_' + place + '_m4cat_re.csv')
# df_m5_re = pd.read_csv(wd + '/data/outputs/' + country_short + '/mov-analysis/by-' + category + '/data_trend_param_' + place + '_m5cat_re.csv')
# df_m6_re = pd.read_csv(wd + '/data/outputs/' + country_short + '/mov-analysis/by-' + category + '/data_trend_param_' + place + '_m6cat_re.csv')
# df_m7_re = pd.read_csv(wd + '/data/outputs/' + country_short + '/mov-analysis/by-' + category + '/data_trend_param_' + place + '_m7cat_re.csv')

df = pd.read_csv(wd + '/data/outputs/' + country_short + '/mov-analysis/by-' + category + '/data_trend_netflows_capital_param_tidy_results_cats.csv')
df_m3_re = pd.read_csv(wd + '/data/outputs/' + country_short + '/mov-analysis/by-' + category + '/data_trend_param_' + place + '_m3cats_re.csv')
df_m4_re = pd.read_csv(wd + '/data/outputs/' + country_short + '/mov-analysis/by-' + category + '/data_trend_param_' + place + '_m4cats_re.csv')
df_m5_re = pd.read_csv(wd + '/data/outputs/' + country_short + '/mov-analysis/by-' + category + '/data_trend_param_' + place + '_m5cats_re.csv')
df_m6_re = pd.read_csv(wd + '/data/outputs/' + country_short + '/mov-analysis/by-' + category + '/data_trend_param_' + place + '_m6cats_re.csv')
df_m7_re = pd.read_csv(wd + '/data/outputs/' + country_short + '/mov-analysis/by-' + category + '/data_trend_param_' + place + '_m7cats_re.csv')

# %%
df6 = df[df['model']==6].reset_index(drop=True)
df6
# Out:
#    model    effect component                   term   estimate  std.error  \
# 0      6     fixed      cond            (Intercept) -65.288835   2.751418
# 1      6     fixed      cond                   time   0.352915   0.049792
# 2      6     fixed      cond                  time2  -0.000383   0.000041
# 3      6     fixed      cond       stringency_index   0.004367   0.003630
# 4      6  ran_pars      cond        sd__(Intercept)   6.106704        NaN
# 5      6  ran_pars      cond               sd__time   0.111091        NaN
# 6      6  ran_pars      cond  cor__(Intercept).time  -0.564807        NaN
# 7      6  ran_pars      cond        sd__Observation   0.621158        NaN
#
#    statistic        p.value     group
# 0 -23.729163  1.803436e-124       NaN
# 1   7.087758   1.363020e-12       NaN
# 2  -9.395144   5.713961e-21       NaN
# 3   1.203120   2.289298e-01       NaN
# 4        NaN            NaN       cat
# 5        NaN            NaN       cat
# 6        NaN            NaN       cat
# 7        NaN            NaN  Residual

# %%
df_m6_re
# Out:
#     estimate   conf.low  conf.high            facet  term           title  \
# 0  16.087948  11.570719  20.605177  cat (Intercept)     0  Random effects
# 1   0.333680  -4.183550   4.850910  cat (Intercept)     1  Random effects
# 2  -3.526745  -8.043973   0.990483  cat (Intercept)     2  Random effects
# 3   6.789705   2.272477  11.306934  cat (Intercept)     3  Random effects
# 4 -19.684754 -24.201982 -15.167525  cat (Intercept)     4  Random effects
# 5  -0.115296  -0.474140   0.243548             time     0  Random effects
# 6   0.049500  -0.309346   0.408345             time     1  Random effects
# 7   0.015986  -0.342858   0.374830             time     2  Random effects
# 8  -0.048384  -0.407228   0.310460             time     3  Random effects
# 9   0.098195  -0.260649   0.457040             time     4  Random effects
#
#    reihe group  p.label  xpos   xmin   xmax
# 0      1   pos      NaN     1  0.825  1.175
# 1      2   pos      NaN     2  1.825  2.175
# 2      3   neg      NaN     3  2.825  3.175
# 3      4   pos      NaN     4  3.825  4.175
# 4      5   neg      NaN     5  4.825  5.175
# 5      1   neg      NaN     1  0.825  1.175
# 6      2   pos      NaN     2  1.825  2.175
# 7      3   pos      NaN     3  2.825  3.175
# 8      4   neg      NaN     4  3.825  4.175
# 9      5   pos      NaN     5  4.825  5.175

# %%
fe_intercept = df6[df6['term'].str.contains('Intercept')]['estimate'].reset_index(drop=True).loc[0]
re_intercept = df_m6_re[df_m6_re['facet'].str.contains('Intercept')].reset_index(drop=True)
intercept = list([fe_intercept + re_intercept['estimate'].loc[i] for i in range(len(np.unique(df_m6_re['term'])))])

# %%
fe_slope = df6[df6['term']=='time']['estimate'].reset_index(drop=True).loc[0]
re_slope = df_m6_re[df_m6_re['facet']=='time'].reset_index(drop=True)
slope = list([fe_slope + re_slope['estimate'].loc[i] for i in range(len(np.unique(df_m6_re['term'])))])

# %%
slope[1]**2-4*quad[1]*(75/100)*intercept[1]
# Out:
# 0.08046833210791589

# %%
try:
    stringency = [df6[df6['term']=='time2']['stringency_index'].reset_index(drop=True).loc[0]
                  for i in range(len(intercept))]
except:
    stringency = [0 for i in range(len(intercept))]

slope = [slope[i] + stringency[i] for i in range(len(slope))]

quad = [df6[df6['term']=='time2']['estimate'].reset_index(drop=True).loc[0]
                  for i in range(len(intercept))]

# %%
thresholds = [25, 50, 75, 100]
times = []

for thr in thresholds:
    times_thr = []
    for i in range(len(intercept)):
        if intercept[i]>0 and slope[i]>0:
            times_thr.append(-1)
        else:    
            time_thr = (-slope[i]+np.sqrt(slope[i]**2-4*quad[i]*(thr/100)*intercept[i]))/(2*quad[i])
            if slope[i]**2-4*quad[i]*(thr/100)*intercept[i] >= 0:
                if time_thr > 0:
                    times_thr.append(time_thr)
                else:
                    time_thr = (-slope[i]-np.sqrt(slope[i]**2-4*quad[i]*(thr/100)*intercept[i]))/(2*quad[i])
                    times_thr.append(time_thr)
            else: 
                times_thr.append(np.nan)
        
    times.append(times_thr)

# %%
times
# Out:
# [[57.00534970397124,
#   42.03616552821574,
#   49.14448442916116,
#   51.340954980901344,
#   49.142956024274554],
#  [131.35669904357692,
#   88.09793862176495,
#   104.64736175693959,
#   111.7680519368012,
#   103.23669622340147],
#  [nan,
#   139.62597669039405,
#   169.88995694535723,
#   189.04491097759615,
#   164.17009343536904],
#  [nan,
#   199.2033990939622,
#   253.0773886112496,
#   325.0860339463906,
#   235.46644177040918]]
