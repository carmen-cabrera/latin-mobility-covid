# %%
import matplotlib.pyplot as plt
import numpy as np
import math
import pandas as pd
import statsmodels.api as sm
from scipy.special import gamma, loggamma, factorial
import scipy.stats
from scipy.interpolate import interp1d
from matplotlib.ticker import AutoMinorLocator 
from matplotlib import rc, font_manager
from matplotlib.lines import Line2D
from matplotlib import colors as mcolors
from mycolorpy import colorlist as mcp
from matplotlib import legend_handler
from mpl_toolkits.axes_grid1 import make_axes_locatable, axes_size
import collections
import matplotlib
import shapely.geometry
import shapely.ops 
from geopy.geocoders import Nominatim
import geopandas as gpd
import mapclassify
import jenkspy
import contextily as cx
import os

# %%
wd = os.path.dirname(os.getcwd())

# %%
gdf = gpd.read_file(wd + '/data/GHS_FUA_UCDB2015_GLOBE_R2019A_54009_1K_V1_0/GHS_FUA_UCDB2015_GLOBE_R2019A_54009_1K_V1_0.gpkg')

# %%
gdf = gdf[gdf['Cntry_ISO'] == 'COL'].reset_index(drop=True)

# %%
gdf
# Out:
#     eFUA_ID  UC_num UC_IDs   eFUA_name  Commuting Cntry_ISO Cntry_name  \
# 0      36.0     1.0    419  San Andrés        1.0       COL   Colombia
# 1     222.0     1.0    461      Tumaco        1.0       COL   Colombia
# 2     383.0     1.0    488     Ipiales        1.0       COL   Colombia
# 3     533.0     1.0    492       Pasto        1.0       COL   Colombia
# 4     676.0     1.0    495  La Hormiga        1.0       COL   Colombia
# ..      ...     ...    ...         ...        ...       ...        ...
# 80   4920.0     1.0    706    Saravena        1.0       COL   Colombia
# 81   4945.0     1.0    708     Manaure        0.0       COL   Colombia
# 82   4970.0     1.0    712      Maicao        1.0       COL   Colombia
# 83   4995.0     1.0    714      Uribia        1.0       COL   Colombia
# 84   5019.0     1.0    732      Arauca        1.0       COL   Colombia
#
#     FUA_area  UC_area     FUA_p_2015      UC_p_2015    Com_p_2015  \
# 0       22.0     10.0   69437.539703   60034.636353   9402.903351
# 1        7.0      5.0  132444.025818  131090.597717   1353.428101
# 2       29.0     11.0  121084.967544  113249.682495   7835.285048
# 3       58.0     28.0  416042.428640  401867.377319  14175.051321
# 4        6.0      4.0   53470.707275   52227.718262   1242.989014
# ..       ...      ...            ...            ...           ...
# 80      11.0      8.0   52805.160301   50814.602539   1990.557762
# 81       5.0      5.0  110737.967529  110737.967529      0.000000
# 82      27.0     17.0  150408.155493  146126.575317   4281.580175
# 83       8.0      5.0  105410.971405  104120.638306   1290.333099
# 84      16.0      9.0   80319.561707   75292.595581   5026.966125
#
#                                              geometry
# 0   MULTIPOLYGON (((-8066000.000 1552000.000, -806...
# 1   MULTIPOLYGON (((-7891000.000 223000.000, -7892...
# 2   MULTIPOLYGON (((-7775000.000 103000.000, -7776...
# 3   MULTIPOLYGON (((-7742000.000 152000.000, -7741...
# 4   MULTIPOLYGON (((-7707000.000 51000.000, -77090...
# ..                                                ...
# 80  MULTIPOLYGON (((-7170000.000 860000.000, -7169...
# 81  MULTIPOLYGON (((-7164000.000 1452000.000, -716...
# 82  MULTIPOLYGON (((-7150000.000 1405000.000, -714...
# 83  MULTIPOLYGON (((-7148000.000 1443000.000, -715...
# 84  MULTIPOLYGON (((-7055000.000 874000.000, -7054...
#
# [85 rows x 13 columns]
