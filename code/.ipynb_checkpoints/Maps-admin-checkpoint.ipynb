# %%
import matplotlib.pyplot as plt
import numpy as np
import math
import pandas as pd
import statsmodels.api as sm
from scipy.special import gamma, loggamma, factorial
import scipy.stats
from scipy.interpolate import interp1d
from matplotlib.ticker import AutoMinorLocator 
from matplotlib import rc, font_manager
from matplotlib.lines import Line2D
from matplotlib import colors as mcolors
from mycolorpy import colorlist as mcp
from matplotlib import legend_handler
from matplotlib_scalebar.scalebar import ScaleBar
from mpl_toolkits.axes_grid1 import make_axes_locatable, axes_size
import collections
import matplotlib
import shapely.geometry
import shapely.ops
from shapely.geometry.point import Point
from geopy.geocoders import Nominatim
import geopandas as gpd
import mapclassify
import jenkspy
import contextily as cx
import os
import rioxarray as rx
import pyreadr
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn import metrics
import plots
import seaborn as sns
from prophet import Prophet
import datetime
import warnings
warnings.filterwarnings("ignore")

# %%
wd = os.path.dirname(os.getcwd())

# %%
wd
# Out:
# '/Users/carmen/Documents/GitHub/latin-mobility-covid'

# %%
gdf_shape_world = gpd.read_file(wd + '/data/inputs/boundaries/World_Countries_Generalized.geojson')

# %%
country = "COL"

if country == "ARG":
    country_full = "argentina"
elif country == "CHL":
    country_full = "chile"
elif country == "COL":
    country_full = "colombia"
elif country == "MEX":
    country_full = "mexico"

# %%
gdf_shape_country = gpd.read_file(wd + '/data/inputs/boundaries/gadm41_' + country + '_2.json')

# %%
gdf_admin_mov = gpd.read_file(wd + '/data/outputs/' + country + '/gdf_' + country + '_admin_rdi_mov_evo.gpkg')
gdf_admin_mov = gdf_admin_mov.sort_values(by = ['rdi'], ascending=True).reset_index(drop=True)

# %%
fig,ax = plt.subplots(figsize=(10,9))

ax.spines['bottom'].set_linewidth(0)
ax.spines['top'].set_linewidth(0)
ax.spines['left'].set_linewidth(0)
ax.spines['right'].set_linewidth(0)

# ax.tick_params(axis = 'both', which = 'both', width = 0, length = 0, color = 'k', labelbottom=False, labelleft=False)

bbox = gdf_admin_mov.total_bounds
ax.set_xlim([bbox[0] - (bbox[2]-bbox[0])*(0.5), bbox[2] + (bbox[2]-bbox[0])*0.78])
ax.set_ylim([bbox[1] - (bbox[3]-bbox[1])*0.7, bbox[3] + (bbox[3]-bbox[1])*0.6])

gdf_shape_world.plot(color = 'lightgray', alpha=0.3, edgecolor='white', lw=.2, ax=ax)
gdf_shape_country.plot(color = 'gray', alpha=0.3, edgecolor='white', lw=.2, ax=ax)
gdf_shape_country.plot(color = 'None', alpha=1, edgecolor='white', lw=.2, ax=ax)
gdf_admin_mov.plot(column='rdi', cmap='viridis', scheme='quantiles', k=3, ax=ax)

points = gpd.GeoSeries(
    [Point(-73.5, 40.5), Point(-74.5, 40.5)], crs=4326
)  # Geographic WGS 84 - degrees
points = points.to_crs(3857)  # Projected WGS 84 - meters
distance_meters = points[0].distance(points[1])
ax.add_artist(ScaleBar(distance_meters))

plt.show()
